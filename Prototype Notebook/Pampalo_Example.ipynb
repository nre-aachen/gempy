# %%
# These two lines are necessary only if gempy is not installed
import sys, os
sys.path.append("../")

# Importing gempy
import gempy as gp

# Embedding matplotlib figures into the notebooks
import matplotlib.pyplot as plt
# %matplotlib inline

# Aux imports
import numpy as np

# %% [markdown]
# ### Data Import and Setting Dimensions

# %%
# Importing the data from csv files and settign extent and resolution
geo_data = gp.create_data([0,20000,0,40000,-4000,1000],[5, 5, 5],
                         path_f = "Pampalo_4c_Foliations.csv",
                         path_i = "Pampalo_4c_Points.csv")

# %%
gp.get_raw_data(geo_data, 'interfaces').head()
# Out:
#              X          Y       Z formation         series  order_series
# 0    12821.440  16498.970 -1000.0    Fault2  Default serie             1
# 368  15162.847  31254.625     1.0  Granite3  Default serie             1
# 367  15162.847  29606.060     1.0  Granite3  Default serie             1
# 366  15099.440  27386.838     1.0  Granite3  Default serie             1
# 365  10343.965  39751.074     1.0  Granite3  Default serie             1

# %%
gp.get_raw_data(geo_data, 'foliations').head()
# Out:
#              X           Y       Z     azimuth   dip  polarity formation  \
# 0    12821.440  16773.6000 -1000.0  270.000000  89.0        -1    Fault2
# 324  10470.778  33473.8465     1.0  270.000000  89.0        -1  Granite3
# 323  14163.560  28611.7150 -2000.0   64.210463  70.0         1  Granite3
# 322  13191.550  30251.8950 -2000.0   53.556353  70.0         1  Granite3
# 321  12047.525  31775.8750 -2000.0   52.722677  70.0         1  Granite3
#
#             series  order_series       G_x           G_y       G_z
# 0    Default serie             1  0.999848  1.836690e-16 -0.017452
# 324  Default serie             1  0.999848  1.836690e-16 -0.017452
# 323  Default serie             1  0.846098  4.088290e-01  0.342020
# 322  Default serie             1  0.755928  5.582074e-01  0.342020
# 321  Default serie             1  0.747726  5.691469e-01  0.342020

# %% [markdown]
# ### Plot Input Data

# %%
gp.plot_data(geo_data, direction='x')

# %%
gp.visualize(geo_data)

# %%
gp.get_series(geo_data)
# Out:
#   Default serie
# 0        Fault2
# 1      Granite3
# 2      Granite2
# 3       Granite

# %%
gp.set_data_series(geo_data,
                   {"Granite_Series": ("Granite3", "Granite2", "Granite1"),
                    "Fault2_Series": "Fault2"},
                   order_series = ["Granite_Series",
                                   "Fault2_Series"])

# %%
geo_data.formations
# Out:
# array(['Fault2', 'Granite3', 'Granite2', 'Granite'], dtype=object)

# %%
gp.set_data_series(geo_data,
                   {"Granite3_Series": 'Granite3',
                    "Granite2_Series": "Granite2",
                    "Granite1_Series": "Granite",
                    "Fault2_Series": ["Fault2"]},
                   order_series = ["Fault2_Series",
                                   "Granite3_Series",
                                   "Granite2_Series",
                                   "Granite_Series",
                                   ]
                  )

# %% [markdown]
# ### Computing the Model

# %%
interp_data = gp.InterpolatorInput(geo_data, u_grade=[0,0,0,0],
                                   dtype='float32')
# Out:
# I am in the setting
# float64
# I am here
# [2, 2]

# %%
interp_data.data.foliations
# Out:
#             X         Y         Z     azimuth   dip  polarity formation  \
# 41   0.487015  0.256379  0.500094   91.974994  89.0         1    Fault2
# 158  0.540357  0.514009  0.487587  270.258585  89.0         1    Fault2
# 159   0.54037  0.517295  0.487587  270.195277  89.0         1    Fault2
# 160  0.540368  0.520757  0.487587  269.732403  89.0         1    Fault2
# 161  0.540365   0.52309  0.487587  270.492599  89.0         1    Fault2
# 163   0.54049  0.527724  0.487587  271.648969  89.0         1    Fault2
# 148   0.53134  0.562419  0.487587   63.432812  70.0         1    Fault2
# 164  0.540499  0.530663  0.487587  267.655539  89.0         1    Fault2
# 165  0.540391  0.532892  0.487587  266.830365  89.0         1    Fault2
# 166  0.540291  0.535372  0.487587  268.453078  89.0         1    Fault2
# 167  0.540198  0.538172  0.487587  267.763858  89.0         1    Fault2
# 168  0.540171  0.541067  0.487587  271.211019  89.0         1    Fault2
# ...

# %%
sol = gp.compute_model(interp_data)
# Out:
# [0, 0, 0, 0]
# C:\Users\Alex\Anaconda3\lib\site-packages\scipy\linalg\basic.py:223: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number: 8.125763950594944e-11
#   ' condition number: {}'.format(rcond), RuntimeWarning)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# theano/scan_module/scan_perform.pyx in theano.scan_module.scan_perform.perform (C:\Users\Alex\AppData\Local\Theano\compiledir_Windows-10-10.0.15063-SP0-Intel64_Family_6_Model_61_Stepping_4_GenuineIntel-3.6.0-64\scan_perform\mod.cpp:4490)()
#
# C:\Users\Alex\Anaconda3\lib\site-packages\theano\gof\op.py in rval(p, i, o, n)
#     871             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
# --> 872                 r = p(n, [x[0] for x in i], o)
#     873                 for o in node.outputs:
#
# ...

# %%
gp.plot_section(geo_data, sol[0,0,:], 11)
plt.show()
gp.plot_section(geo_data, sol[1,0,:], 11)
plt.show()
gp.plot_section(geo_data, sol[2,0,:], 11, plot_data=True)
plt.show()
